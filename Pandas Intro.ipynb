# %%
import pandas as pd

#df= pd.read_csv(r"C:\Users\aryam\Downloads\pokemon_data.csv")
#print(df.tail(3))


#df_xlsx= pd.read_excel(r"C:\Users\aryam\Downloads\pokemon_data.xlsx")
#print(df_xlsx.head(3))

df=pd.read_csv(r"C:\Users\aryam\Downloads\pokemon_data.txt",delimiter='\t')
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
##Read Headers
#print(df.columns)

##Read each Columns
#print(df[['Name','Type 1']])

##Read Each Row
#print(df.iloc[1:4])

##Read a specific location (R,C)
print(df.iloc[2,1])
# Out:
# Venusaur

# %%
##Iterate through each row
#for index,row in df.iterrows():
    #print(index,row['Name'])
    
#df.loc[df['Type 1']=="Fire"]
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
#Sorting / Describing Data
#df.describe()
df.sort_values('Name',ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
#Making changes to Data
#df['Total'] = df['HP'] + df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Speed']

#df.head(5)
# always recheck manually calculation

##Removing columns
#df=df.drop(columns=['Total'])

###ANother Way of adding things up
df['Total']=df.iloc[:, 4:10].sum(axis=1)
#axis=1   >> add horizontal
#axis =2 >> add vertically

##Rearranging columns)
cols=list(df.columns)
df = df[cols[0:4]+[cols[-1]]+cols[4:12]]



df.head(5)
# Out:
#    #                   Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur   Grass  Poison    318  45      49       49
# 1  2                Ivysaur   Grass  Poison    405  60      62       63
# 2  3               Venusaur   Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur   Grass  Poison    625  80     100      123
# 4  4             Charmander  Flamer     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
#Saving our Dataframe
#df.to_csv('modiified.csv',index=False)

# %%
df=pd.read_csv('modiified.csv')
print(df)
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  Total  HP  \
# 0             0    1              Bulbasaur    Grass  Poison    318  45
# 1             1    2                Ivysaur    Grass  Poison    405  60
# 2             2    3               Venusaur    Grass  Poison    525  80
# 3             3    3  VenusaurMega Venusaur    Grass  Poison    625  80
# 4             4    4             Charmander     Fire     NaN    309  39
# ..          ...  ...                    ...      ...     ...    ...  ..
# 795         795  719                Diancie     Rock   Fairy    600  50
# 796         796  719    DiancieMega Diancie     Rock   Fairy    700  50
# 797         797  720    HoopaHoopa Confined  Psychic   Ghost    600  80
# 798         798  720     HoopaHoopa Unbound  Psychic    Dark    680  80
# 799         799  721              Volcanion     Fire   Water    600  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.to_excel('modified.xlsx',index=False)

# %%
df.to_csv('modified.txt',index=False,sep='\t')

# %%
#Filtering Data
df.loc[(df['Type 1']=='Grass')   &  (df['Type 2']=='Poison')  & (df['HP']>=70)]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 652  591              Amoonguss  Grass  Poison  114      85       70       85
#
#      Sp. Def  Speed  Generation  Legendary
# 2        100     80           1      False
# 3        120     80           1      False
# 50        90     50           1      False
# 77        70     70           1      False
# 652       80     30           5      False

# %%
## Filtering using Regex Filtering(for Mega pokemons)
df.loc[df['Name'].str.contains('Mega')]

##Put ~ before df before Name and get not Mega pokemons
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 12     9    BlastoiseMega Blastoise     Water       NaN   79     103      120
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150       40
# 23    18        PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 71    65      AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 87    80        SlowbroMega Slowbro     Water   Psychic   95      75      180
# 102   94          GengarMega Gengar     Ghost    Poison   60      65       80
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 137  127          PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %%
import re

#df.loc[df['Type 1'].str.contains('fire|grass',flags=re.I,regex=True)]
##re.I = Ignore Case

#starts with pi
df.loc[df['Name'].str.contains('^pi[a-z]*',flags=re.I,regex=True)]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# ...

# %%
##Conditional Changes

#df.loc[df['Type 1']=='Fire','Type 1'] = 'Flamer'


df.loc[df['Total'] > 500, ['Generation','Legendary']] = 'TEST VALUE'
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander   Flamer     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion   Flamer   Water    600  80     110      120
#
# ...

# %%
#Aggregate Statistics

##For Defense ( Can be altered to different needs)
#df.groupby(['Type 1']).mean().sort_values('Defense',ascending=False)


df['count'] = 1

##Counts of Different types of pokemon(Can be grouped by multiple parameters)
df.groupby(['Type 1']).count()['count']
# Useful with Big Humungous Data sets
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Flamer       52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
##Working with Large AMounts of Data#5 rows passed at a time
#for df in pd.read_csv('modified.csv',chunksize=5):
   # print("Chunk Data Frame")
   # print(df)

new_df = pd.DataFrame(columns=df.columns)
for df in pd.read_csv('modified.csv',chunksize=5):
    results = df.groupby(['Type 1']).count()
    
    new_df = pd.concat([new_df, results])
    ##new df can have more data from the mega file to get your work done efficiently
    #within memory limit
